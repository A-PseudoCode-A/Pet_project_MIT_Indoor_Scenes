# %% [markdown]
# ### Итог обучения RCF (50 estimators), без PCA
#
# Accuracy: 0.10711994868505452
#
# Clf report:
#
#                precision    recall    f1-score   support
#
#            0       0.09      0.17      0.12       126
#            1       0.00      0.00      0.00        23
#            2       0.12      0.03      0.05        33
#            3       0.06      0.08      0.07        78
#            4       0.08      0.24      0.12       108
#            5       0.14      0.12      0.13        41
#            6       0.11      0.41      0.17       129
#            7       0.00      0.00      0.00        75
#            8       0.12      0.09      0.10        43
#            9       0.00      0.00      0.00        25
#           10       0.16      0.30      0.21        99
#           11       0.00      0.00      0.00        34
#           12       0.20      0.03      0.04        40
#           13       0.00      0.00      0.00        31
#           14       0.00      0.00      0.00        18
#
#     macro avg      0.13      0.06      0.06      3118
#     weighted avg   0.12      0.11      0.08      3118
